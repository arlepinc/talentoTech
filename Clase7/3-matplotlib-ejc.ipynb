# %%
#INTRODUCCION A MATBLOTLIB

#importando el modulo pyplot para  poder trabajar con gráficas en matplotlib
import matplotlib.pyplot as plt

# %%
lista = [1,5,5,7,2,3,1,8]
plt.plot(lista) #genera la grafica a partir de la lista que le entregamos
plt.show #muestra la grafica
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#al pasarle dos listas la primera es el eje x y la segunda el eje y
plt.plot([-3,-2,-1,0,1,2,3],[1,2,3,4,5,6,7])
plt.show()

# %%
plt.plot([-3,-2,-1,0,1,2,3],[1,2,3,4,5,6,7])
plt.axis([1,8,2,10]) # [xmin, xmax, ymin, ymax] #permite modificar las longuitudes para que la figura no se vea ajutada 
plt.show()

# %%
#USANDO NUMPY PARA GENERAR GRAFICAS A PARTIR DE UN ARRAY y funciones matematicas

import numpy as np


x = np.linspace(-2,2,500)
print(f"Array de x:\n{x}")
y = x**2

plt.plot(x,y)
plt.show()
# Out:
# Array de x:
# [-2.         -1.99198397 -1.98396794 -1.9759519  -1.96793587 -1.95991984
#  -1.95190381 -1.94388778 -1.93587174 -1.92785571 -1.91983968 -1.91182365
#  -1.90380762 -1.89579158 -1.88777555 -1.87975952 -1.87174349 -1.86372745
#  -1.85571142 -1.84769539 -1.83967936 -1.83166333 -1.82364729 -1.81563126
#  -1.80761523 -1.7995992  -1.79158317 -1.78356713 -1.7755511  -1.76753507
#  -1.75951904 -1.75150301 -1.74348697 -1.73547094 -1.72745491 -1.71943888
#  -1.71142285 -1.70340681 -1.69539078 -1.68737475 -1.67935872 -1.67134269
#  -1.66332665 -1.65531062 -1.64729459 -1.63927856 -1.63126253 -1.62324649
#  -1.61523046 -1.60721443 -1.5991984  -1.59118236 -1.58316633 -1.5751503
#  -1.56713427 -1.55911824 -1.5511022  -1.54308617 -1.53507014 -1.52705411
#  -1.51903808 -1.51102204 -1.50300601 -1.49498998 -1.48697395 -1.47895792
#  -1.47094188 -1.46292585 -1.45490982 -1.44689379 -1.43887776 -1.43086172
#  -1.42284569 -1.41482966 -1.40681363 -1.3987976  -1.39078156 -1.38276553
# ...

# %%
plt.plot(x, y)
plt.title("square fuction") #titulo de la grafica
plt.xlabel('X')  #label for x axis
plt.ylabel('Y = X**2')  #nombre para el eje Y
plt.grid(True)   #mostrar rejilla de cuadricula
plt.show()      #muestra la gráfica en pantalla

# %%
#SOBRESPONER GARFICAS Y CAMBIAR ESTILOS SW LINea

import numpy as np


x = np.linspace(-2,2,500)
print(f"Array de x:\n{x}")
y = x**2
Y2 = x +1  #Linea que se va a graf

plt.plot(x,y,'b--',x,Y2,'r.-')   #Grafica con dos curvas: una para y=x^2 y otra para y=x+1omillas es el color en ingles con la inicial
plt.show()
# Out:
# Array de x:
# [-2.         -1.99198397 -1.98396794 -1.9759519  -1.96793587 -1.95991984
#  -1.95190381 -1.94388778 -1.93587174 -1.92785571 -1.91983968 -1.91182365
#  -1.90380762 -1.89579158 -1.88777555 -1.87975952 -1.87174349 -1.86372745
#  -1.85571142 -1.84769539 -1.83967936 -1.83166333 -1.82364729 -1.81563126
#  -1.80761523 -1.7995992  -1.79158317 -1.78356713 -1.7755511  -1.76753507
#  -1.75951904 -1.75150301 -1.74348697 -1.73547094 -1.72745491 -1.71943888
#  -1.71142285 -1.70340681 -1.69539078 -1.68737475 -1.67935872 -1.67134269
#  -1.66332665 -1.65531062 -1.64729459 -1.63927856 -1.63126253 -1.62324649
#  -1.61523046 -1.60721443 -1.5991984  -1.59118236 -1.58316633 -1.5751503
#  -1.56713427 -1.55911824 -1.5511022  -1.54308617 -1.53507014 -1.52705411
#  -1.51903808 -1.51102204 -1.50300601 -1.49498998 -1.48697395 -1.47895792
#  -1.47094188 -1.46292585 -1.45490982 -1.44689379 -1.43887776 -1.43086172
#  -1.42284569 -1.41482966 -1.40681363 -1.3987976  -1.39078156 -1.38276553
# ...

# %%
#SEPARANDO DOS FUNCIONES CAD UNA EN UN PLOT

import numpy as np


x = np.linspace(-2,2,500)
# print(f"Array de x:\n{x}")
y = x**2    #Función que se va a graficar en el eje y
Y2 = x +1  # funcion de la Linea que se va a graficar

plt.plot(x,y,'b--')   
plt.plot(x,Y2,'r.-')
plt.show()
# Out:
# Array de x:
# [-2.         -1.99198397 -1.98396794 -1.9759519  -1.96793587 -1.95991984
#  -1.95190381 -1.94388778 -1.93587174 -1.92785571 -1.91983968 -1.91182365
#  -1.90380762 -1.89579158 -1.88777555 -1.87975952 -1.87174349 -1.86372745
#  -1.85571142 -1.84769539 -1.83967936 -1.83166333 -1.82364729 -1.81563126
#  -1.80761523 -1.7995992  -1.79158317 -1.78356713 -1.7755511  -1.76753507
#  -1.75951904 -1.75150301 -1.74348697 -1.73547094 -1.72745491 -1.71943888
#  -1.71142285 -1.70340681 -1.69539078 -1.68737475 -1.67935872 -1.67134269
#  -1.66332665 -1.65531062 -1.64729459 -1.63927856 -1.63126253 -1.62324649
#  -1.61523046 -1.60721443 -1.5991984  -1.59118236 -1.58316633 -1.5751503
#  -1.56713427 -1.55911824 -1.5511022  -1.54308617 -1.53507014 -1.52705411
#  -1.51903808 -1.51102204 -1.50300601 -1.49498998 -1.48697395 -1.47895792
#  -1.47094188 -1.46292585 -1.45490982 -1.44689379 -1.43887776 -1.43086172
#  -1.42284569 -1.41482966 -1.40681363 -1.3987976  -1.39078156 -1.38276553
# ...

# %%
import numpy as np


x = np.linspace(-2,2,500)
# print(f"Array de x:\n{x}")
y = x**2    #Función que se va a graficar en el eje y
y2 = x + 1  # funcion de la Linea que se va a graficar

plt.plot(x,y,'b--', label = "x**2")   
plt.plot(x,y2,'r.-', label = "x+1")
plt.legend(loc="best") #ubica la leyenda en la mejor localizacion de la grafica, como las convenciones d elos mapas
plt.show()

# %%
#CREAR SUBPLOt PARA PONER UNA GRAFICA EN UN DETERMINADO ESPACIO DE UN GRID, ALGO ASI COMO POSICIONAR ELEMENTOS EN CSS GRID

import numpy as np


x = np.linspace(-2,2,500)
# print(f"Array de x:\n{x}")
y = x**2    #Función que se va a graficar en el eje y
y2 = x + 1  # funcion de la linea que se va a graficar

plt.subplot(1,2,1)   #creamos una subfigura el primer valor es las filas rows, el segundo las columnas y el tercero le enterga la posiciona ocupar
plt.plot(x,y,'b--')   
plt.subplot(1,2,2)   #creamos una subfigura el primer valor es las filas rows, el segundo las columnas y el tercero le enterga la posiciona ocupar
plt.plot(x,y2,'r.-')
plt.show()

# %%
#Scatter Plots sirve para graficar puntos de dispersion, otro tipo de grafica para estadistica 

#importacion de random para generar arrrays  aleatorios y matplotlib para hacer el gráfico.
import numpy as np
import matplotlib.pyplot as plt

#generamos un array con numeros aleatorios                                                  
from numpy.random import rand

x,y = rand(2,100)
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ESTABLECIENDO DOS SCATTER POR SEPARADOS CON COLORES DISTINTOS

from numpy.random import rand

x,y = rand(2,100)
x2,y2 = rand(2,100)
plt.scatter(x,y, c = 'red')
plt.scatter(x2, y2, c='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#GENERANDO HISTOGRAMAS CON HIST

data = [1,1.1,1.8,2,2.1,3.2,3,3,3,3]

plt.subplot(211)
plt.hist(data, bins=10, alpha=0.7)
plt.show
plt.savefig('histograma.png')

# %%
#GURDAR LAS FIGURAS  GENERADAS EN EL PC DE FORMA LOCAL con la funcion SAVEFILE

from numpy.random import rand

x,y = rand(2,100)
x2,y2 = rand(2,100)
plt.scatter(x,y, c = 'red')
plt.scatter(x2, y2, c='blue')
plt.show
plt.savefig("grafica.png", transparent = True )
