# %%
import pandas as pd
 #conocer la version de pandas 
pd.__version__
# Out:
# '2.2.2'

# %%
#importamos un archivo local, con la funcin r y la ruta local, si hay problemas con la imprtanacion hay que revisar que el archivo este guradado con 
#codificacion UTF-8

# df = pd.read_csv(r'D:\Clase7\archivosDF\dataframe.csv')
# df

df2 = pd.read_csv(r'D:\Clase7\archivosDF\dataframeutf8.csv')
print(df2)

#Accesoa varias columnas
df2[["Edad",'Automovil']]
 #acceso a una sola columna con espacios en el nombre_columna
df2['Nombre y apellido']
# Out:
#   Nombre y apellido  Edad       País Automovil
# 0              Juan    35     Mexico        No
# 1             Pedro    41   Honduras        Si
# 2             Maria    28       Peru        Si
# 3             Laura    66  Argentina        No
#   Nombre y apellido
# 0              Juan
# 1             Pedro
# 2             Maria
# 3             Laura

# %%
#importantadno archivos mas robustos .csv
df3  = pd.read_csv(r'D:\Clase7\archivosDF\ejemplo.csv')
df3
# Out:
#            fecha    apertura        alto        bajo      cierre  Adj cierre  \
# 0     1999-12-31  146.843704  147.500000  146.250000  146.875000  104.415031
# 1     2000-01-03  148.250000  148.250000  143.875000  145.437500  103.393074
# 2     2000-01-04  143.531204  144.062500  139.640594  139.750000   99.349785
# 3     2000-01-05  139.937500  141.531204  137.250000  140.000000   99.527527
# 4     2000-01-06  139.625000  141.500000  137.750000  137.750000   97.928017
# ...          ...         ...         ...         ...         ...         ...
# 4625  2018-05-21  273.010010  273.980011  272.570007  273.369995  273.369995
# 4626  2018-05-22  273.959991  274.250000  272.239990  272.609985  272.609985
# 4627  2018-05-23  271.170013  273.390015  270.989990  273.359985  273.359985
# 4628  2018-05-24  272.910004  273.220001  270.779999  272.799988  272.799988
# 4629  2018-05-25  272.149994  272.859985  271.579987  272.149994  272.149994
#
#        volumen
# 0      3172700
# ...

# %%
#Para importar archivos de excel es necesario instalar la dependecia openyxl con este comando "pip install openpyxl"
excel = pd.read_excel(r'D:\Clase7\archivosDF\Listado-de-proveedores-y-contactos.xlsx')
excel
# Out:
#         ID     Proveedor           Contacto comercial               Email  \
# 0    P0001    So Factive         Lorenzo Cantón Galan  fluffy@verizon.net
# 1    P0002    Kontroller          Adelina Valls Canet      fraterk@me.com
# 2    P0003   Finance Api          Eulalia del Galindo     animats@mac.com
# 3    P0004   Biomotivate         Tania Catalán Galván    tbeck@icloud.com
# 4    P0005     Deltavita          Abraham Girón-Soler  mallanmba@yahoo.ca
# ..     ...           ...                          ...                 ...
# 994  P0995       Actenet                Gabriel Arnau    telbij@yahoo.com
# 995  P0996     Datawrite           Gala Millán Ribera      payned@mac.com
# 996  P0997  Echo Digital  Luis Ángel Llanos Benavente     chrwin@live.com
# 997  P0998      Meussicz         Tere Monreal Botella     stellaau@me.com
# 998  P0999       Learnig           Pepito Catalá-Niño   elmer@verizon.net
#
#            Teléfono  Saldo pendiente Fecha de última compra
# ...

# %%
#importando un archivo .json
json = pd.read_json(r'D:\Clase7\archivosDF\archivo.json')
json
# Out:
#            localidade 1      localidade 2      localidade 3    localidade 4  \
# Continente       África  América do Norte   América Central  América do Sul
# País             Angola    Estados Unidos            México          Brasil
# Capital          Luanda     Washington DC  Cidade do México        Brasília
#
#            localidade 5 localidade 6 localidade 7 localidade 8
# Continente       Europa       Europa      Oceania         Ásia
# País            Espanha     Alemanha    Austrália        Japão
# Capital           Madri       Berlim     Camberra       Tóquio

# %%
df = pd.read_csv(r'D:\Clase7\archivosDF\dataframe.csv')
df
df.shape
df.head(3) #consulta las primeras tres filas
df.tail(2) #conuslta los ultimos registros del df
df.info() #arroja informacion del df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     5 non-null      object
#  1   Edad       5 non-null      int64
#  2   Pais       5 non-null      object
#  3   Automovil  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes
